# %% [markdown]
# ## QUEST: Quantifying Uncertainty for EnSemble Tree Models

# %%
import sys
sys.path.append("../")
from QUEST import QUESTExplainerRegressor
# Out:
# /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("../datasets/Ovarian_patient_data 2.csv")

# %%
df.head()
# Out:
#              Timestamp        Age        BMI  Comorbidity  Symptom  \
# 0  2019-01-01 00:00:00  67.450712  27.468755            0        0
# 1  2019-01-01 01:00:00  57.926035  27.736019            1        0
# 2  2019-01-01 02:00:00  69.715328  22.285561            0        0
# 3  2019-01-01 03:00:00  82.845448  31.315519            1        1
# 4  2019-01-01 04:00:00  56.487699  17.056296            1        0
#
#         CA125  CancerStage Histopathology  PreviousTreatment MenstrualHistory  \
# 0   66.738329            0         serous                  0          regular
# 1   28.390526            1     clear cell                  0          regular
# 2  118.120787            3     clear cell                  1          regular
# 3    6.418598            0         serous                  1          regular
# 4   65.912779            1       mucinous                  0          regular
#
#    ... RadiomicIntensity  RadiomicShape  DopplerVelocity Parity  \
# 0  ...         57.572038       1.285647         1.948916      0
# 1  ...         44.385558       0.656970         3.589821      0
# 2  ...         35.711312       1.034179         3.625658      0
# 3  ...         49.922109       1.000078         1.108221      0
# 4  ...         43.547336       1.415819         1.030482      2
#
#   OralContraceptives  HormoneTherapy  MenarcheAge  MenopauseAge  RiskLabel  \
# 0                  0               0    12.077803     54.947593          2
# 1                  0               0    12.745908     46.864164          0
# 2                  0               0    12.495603     55.757130          0
# 3                  0               0    12.577276     50.462495          1
# 4                  0               0    14.698884     58.628299          0
#
#    ProgressionProbability
# 0                0.176654
# 1                0.343371
# 2                0.036907
# 3                0.161943
# 4                0.554210
#
# [5 rows x 34 columns]

# %%
df.drop(["Timestamp"], axis =1, inplace=True)

# %%
for i in df.columns:
    data_types = i+":"+str(df[i].dtype)
    print(data_types)
# Out:
# Age:float64
# BMI:float64
# Comorbidity:int64
# Symptom:int64
# CA125:float64
# CancerStage:int64
# Histopathology:object
# PreviousTreatment:int64
# MenstrualHistory:object
# Ethnicity:object
# Smoking:int64
# Alcohol:int64
# Residence:object
# SocioeconomicStatus:object
# BRCA_Mutation:int64
# GeneExpression:float64
# SNP_Status:int64
# DNAMethylation:float64
# miRNA:float64
# TumorSize:float64
# TumorLocation:object
# EnhancementPattern:float64
# RadiomicTexture:float64
# RadiomicIntensity:float64
# RadiomicShape:float64
# DopplerVelocity:float64
# Parity:int64
# OralContraceptives:int64
# HormoneTherapy:int64
# MenarcheAge:float64
# MenopauseAge:float64
# RiskLabel:int64
# ProgressionProbability:float64

# %%
feature_names = ["MenstrualHistory", "Histopathology", "Ethnicity", "Residence", "SocioeconomicStatus", "TumorLocation"]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_MenstrualHistory = LabelEncoder()
le_Histopathology= LabelEncoder()
le_Ethnicity= LabelEncoder()
le_Residence= LabelEncoder()
le_SocioeconomicStatus= LabelEncoder()
le_TumorLocation= LabelEncoder()

# %%
df["MenstrualHistory"] = le_MenstrualHistory.fit_transform(df["MenstrualHistory"])
df["Histopathology"] = le_MenstrualHistory.fit_transform(df["Histopathology"])
df["Ethnicity"] = le_MenstrualHistory.fit_transform(df["Ethnicity"])
df["Residence"] = le_MenstrualHistory.fit_transform(df["Residence"])
df["SocioeconomicStatus"] = le_MenstrualHistory.fit_transform(df["SocioeconomicStatus"])
df["TumorLocation"] = le_MenstrualHistory.fit_transform(df["TumorLocation"])

# %%
from sklearn.model_selection import train_test_split
X = df.drop(["RiskLabel","ProgressionProbability"], axis = 1)
y = df[["RiskLabel"]]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.4)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=5, random_state=42)
model.fit(X_train, y_train)
# Out:
# /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=5, random_state=42)
